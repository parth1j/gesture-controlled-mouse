# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from sklearn.preprocessing import StandardScaler
import shutil
import array as arr

# %%
from google.colab import files
files.upload()
# Out:
#      <input type="file" id="files-f539f65e-8fd0-4bd6-81d5-c18728cda73d" name="files[]" multiple disabled />
#      <output id="result-f539f65e-8fd0-4bd6-81d5-c18728cda73d">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script src="/nbextensions/google.colab/files.js"></script>
# Saving kaggle.json to kaggle (1).json
# {'kaggle.json': b'{"username":"rohanlimaye20","key":"198f207519dc2f20fce5deeb37af6b0e"}'}

# %%
# !pip install -q kaggle
# !mkdir -p ~/.kaggle
# !cp kaggle.json ~/.kaggle/
# !chmod 600 /root/.kaggle/kaggle.json

# %%
# !kaggle datasets download -d andrewmvd/ocular-disease-recognition-odir5k
# Out:
# ocular-disease-recognition-odir5k.zip: Skipping, found more recently modified local copy (use --force to force download)

# %%
import os
import zipfile
local='/content/ocular-disease-recognition-odir5k.zip'
zipr=zipfile.ZipFile(local,'r')
zipr.extractall('/content')
zipr.close()

# %%
meta=pd.read_excel('/content/ODIR-5K/data.xlsx')

# %%
meta.head(25)
# Out:
#     ID  Patient Age Patient Sex  Left-Fundus  Right-Fundus  ...  C  A  H  M  O
# 0    0           69      Female   0_left.jpg   0_right.jpg  ...  1  0  0  0  0
# 1    1           57        Male   1_left.jpg   1_right.jpg  ...  0  0  0  0  0
# 2    2           42        Male   2_left.jpg   2_right.jpg  ...  0  0  0  0  1
# 3    3           66        Male   3_left.jpg   3_right.jpg  ...  0  0  0  0  1
# 4    4           53        Male   4_left.jpg   4_right.jpg  ...  0  0  0  0  1
# 5    5           50      Female   5_left.jpg   5_right.jpg  ...  0  0  0  0  0
# 6    6           60        Male   6_left.jpg   6_right.jpg  ...  0  0  0  0  1
# 7    7           60      Female   7_left.jpg   7_right.jpg  ...  0  0  0  0  1
# 8    8           59        Male   8_left.jpg   8_right.jpg  ...  0  0  0  0  0
# 9    9           54        Male   9_left.jpg   9_right.jpg  ...  0  0  0  0  1
# 10  10           70        Male  10_left.jpg  10_right.jpg  ...  0  0  0  0  1
# 11  11           60      Female  11_left.jpg  11_right.jpg  ...  0  0  1  0  0
# 12  12           65        Male  12_left.jpg  12_right.jpg  ...  0  0  0  0  1
# 13  13           60      Female  13_left.jpg  13_right.jpg  ...  0  0  0  1  0
# 14  14           55        Male  14_left.jpg  14_right.jpg  ...  0  0  0  0  1
# 15  15           50        Male  15_left.jpg  15_right.jpg  ...  0  0  0  0  1
# 16  16           54      Female  16_left.jpg  16_right.jpg  ...  0  0  0  1  0
# 17  17           57        Male  17_left.jpg  17_right.jpg  ...  0  0  0  0  1
# 18  18           58        Male  18_left.jpg  18_right.jpg  ...  0  0  0  1  0
# 19  19           45        Male  19_left.jpg  19_right.jpg  ...  0  0  0  0  0
# 20  20           64      Female  20_left.jpg  20_right.jpg  ...  0  0  0  0  1
# 21  21           76      Female  21_left.jpg  21_right.jpg  ...  0  0  0  0  1
# 22  22           55      Female  22_left.jpg  22_right.jpg  ...  0  0  0  0  1
# 23  23           47        Male  23_left.jpg  23_right.jpg  ...  0  0  1  0  0
# 24  24           75      Female  24_left.jpg  24_right.jpg  ...  1  0  0  0  0
#
# [25 rows x 15 columns]

# %%
classes=["normal fundus",'retinopathy','glaucoma','cataract','age-related macular degeneration','hypertensive retinopathy','myopia']
for x in classes:
  print(x)
# Out:
# normal fundus
# retinopathy
# glaucoma
# cataract
# age-related macular degeneration
# hypertensive retinopathy
# myopia

# %% [markdown]
# NOTE:
# age-related macular degeneration---stands for AMD

# %% [markdown]
# hypertensive retinopathy--- stands for hypertension

# %% [markdown]
# retinopathy ---stands for diabetes

# %%
to_create = [
    '/content/eye',
     '/content/eye/age-related macular degeneration',
     '/content/eye/cataract',
     '/content/eye/retinopathy',
     '/content/eye/glaucoma',
     '/content/eye/hypertensive retinopathy',
     '/content/eye/myopia',
      '/content/eye/normal fundus',
       '/content/eye/other',

]

for directory in to_create:
    try:
        os.mkdir(directory)
        print(directory, 'created')
    except:
        print(directory, 'failed')
# Out:
# /content/eye created
# /content/eye/age-related macular degeneration created
# /content/eye/cataract created
# /content/eye/retinopathy created
# /content/eye/glaucoma created
# /content/eye/hypertensive retinopathy created
# /content/eye/myopia created
# /content/eye/normal fundus created
# /content/eye/other created

# %%
a = arr.array('i', [0, 0, 0,0,0,0,0,0])

# %%
for x,k in zip(meta['Left-Diagnostic Keywords'],meta['ID']):
 comma=x.count(chr(65292))
 path="/content/ODIR-5K/Training Images/"+ str(k) +"_left.jpg"
 m=0
 i=0  
 for j in classes: 
  if (x.count(j)>0):
   if(j=='retinopathy'):
     if(x.find("hypertensive retinopathy") != -1):
       if (x.count(j)>1):
         shutil.copy(path,'/content/eye/'+j)
         a[i]+=1
         m+=1
     else:
       shutil.copy(path,'/content/eye/'+j)
       a[i]+=1
       m+=1
   else:
     if(j=="normal fundus"):
       m+=1
       if(comma==0):
          shutil.copy(path,'/content/eye/'+j)
          a[i]+=1
       elif(comma==1):
         if(x.find("lens dust") != -1):
           shutil.copy(path,'/content/eye/'+j)
           a[i]+=1
     
     else:
      shutil.copy(path,'/content/eye/'+j)
      a[i]+=1
      m+=1
  i+=1 
 if(m<comma+1):
   if(x.find("lens dust") != -1):
     if(m<comma):
       shutil.copy(path,'/content/eye/other')
       a[7]+=1
   else:
    shutil.copy(path,'/content/eye/other')
    a[7]+=1

# %%
for x,k in zip(meta['Right-Diagnostic Keywords'],meta['ID']):
 comma=x.count(chr(65292))
 path="/content/ODIR-5K/Training Images/"+ str(k) +"_right.jpg"
 m=0
 i=0  
 for j in classes:
  if (x.count(j)>0):
   if(j=='retinopathy'):
     if(x.find("hypertensive retinopathy") != -1):
       if (x.count(j)>1):
         shutil.copy(path,'/content/eye/'+j)
         a[i]+=1
         m+=1
     else:
       shutil.copy(path,'/content/eye/'+j)
       a[i]+=1
       m+=1
   else:
     if(j=="normal fundus"):
       m+=1
       if(comma==0):
          shutil.copy(path,'/content/eye/'+j)
          a[i]+=1
       elif(comma==1):
         if(x.find("lens dust") != -1):
           shutil.copy(path,'/content/eye/'+j)
           a[i]+=1
     
     else:
      shutil.copy(path,'/content/eye/'+j)
      a[i]+=1
      m+=1
  i+=1 
 if(m<comma+1):
   if(x.find("lens dust") != -1):
     if(m<comma):
       shutil.copy(path,'/content/eye/other')
       a[7]+=1
   else:
    shutil.copy(path,'/content/eye/other')
    a[7]+=1

# %%
#shutil.rmtree('/content/eye', ignore_errors=True)

# %%
# %matplotlib inline

from imutils import paths
import cv2
import os
import matplotlib.pyplot as plt
import numpy as np
import tensorflow as tf
import random
import seaborn as sns

from sklearn import metrics
from sklearn.model_selection import train_test_split
from sklearn.metrics import classification_report,confusion_matrix
from sklearn.preprocessing import LabelBinarizer

from keras.models import Sequential
from keras.layers import Dense,Flatten,Conv2D,MaxPooling2D,AveragePooling2D,Dropout
from keras.optimizers import SGD,RMSprop,Adam


sns.set()
# Out:
# /usr/local/lib/python3.6/dist-packages/statsmodels/tools/_testing.py:19: FutureWarning: pandas.util.testing is deprecated. Use the functions in the public API at pandas.testing instead.
#   import pandas.util.testing as tm

# %%
imagePaths = sorted(list(paths.list_images('/content/eye')))
imagePaths
# Out:
# ['/content/eye/amd/102_left.jpg',
#  '/content/eye/amd/102_right.jpg',
#  '/content/eye/amd/1043_left.jpg',
#  '/content/eye/amd/1043_right.jpg',
#  '/content/eye/amd/1064_left.jpg',
#  '/content/eye/amd/1064_right.jpg',
#  '/content/eye/amd/1065_left.jpg',
#  '/content/eye/amd/1075_left.jpg',
#  '/content/eye/amd/1085_left.jpg',
#  '/content/eye/amd/1085_right.jpg',
#  '/content/eye/amd/1091_left.jpg',
#  '/content/eye/amd/1091_right.jpg',
#  '/content/eye/amd/1098_left.jpg',
#  '/content/eye/amd/1098_right.jpg',
#  '/content/eye/amd/1104_left.jpg',
#  '/content/eye/amd/1104_right.jpg',
#  '/content/eye/amd/1111_left.jpg',
#  '/content/eye/amd/1111_right.jpg',
#  '/content/eye/amd/1125_left.jpg',
#  '/content/eye/amd/1125_right.jpg',
#  '/content/eye/amd/1154_left.jpg',
#  '/content/eye/amd/1154_right.jpg',
#  '/content/eye/amd/1168_right.jpg',
#  '/content/eye/amd/1191_left.jpg',
#  '/content/eye/amd/1196_left.jpg',
#  '/content/eye/amd/1196_right.jpg',
#  '/content/eye/amd/1197_left.jpg',
#  '/content/eye/amd/1197_right.jpg',
#  '/content/eye/amd/1202_left.jpg',
#  '/content/eye/amd/1202_right.jpg',
#  '/content/eye/amd/1243_right.jpg',
#  '/content/eye/amd/126_left.jpg',
#  '/content/eye/amd/126_right.jpg',
#  '/content/eye/amd/1280_left.jpg',
#  '/content/eye/amd/1295_left.jpg',
#  '/content/eye/amd/1295_right.jpg',
#  '/content/eye/amd/1314_left.jpg',
#  '/content/eye/amd/1314_right.jpg',
#  '/content/eye/amd/136_left.jpg',
#  '/content/eye/amd/1458_left.jpg',
#  '/content/eye/amd/1458_right.jpg',
#  '/content/eye/amd/152_left.jpg',
#  '/content/eye/amd/152_right.jpg',
#  '/content/eye/amd/153_right.jpg',
#  '/content/eye/amd/158_left.jpg',
#  '/content/eye/amd/158_right.jpg',
#  '/content/eye/amd/160_right.jpg',
#  '/content/eye/amd/162_left.jpg',
#  '/content/eye/amd/162_right.jpg',
#  '/content/eye/amd/164_left.jpg',
#  '/content/eye/amd/164_right.jpg',
#  '/content/eye/amd/168_left.jpg',
#  '/content/eye/amd/168_right.jpg',
#  '/content/eye/amd/178_left.jpg',
#  '/content/eye/amd/178_right.jpg',
#  '/content/eye/amd/1799_right.jpg',
#  '/content/eye/amd/1801_right.jpg',
#  '/content/eye/amd/1817_left.jpg',
#  '/content/eye/amd/1817_right.jpg',
#  '/content/eye/amd/1819_left.jpg',
#  '/content/eye/amd/1819_right.jpg',
#  '/content/eye/amd/1820_left.jpg',
#  '/content/eye/amd/1820_right.jpg',
#  '/content/eye/amd/1829_left.jpg',
#  '/content/eye/amd/1829_right.jpg',
#  '/content/eye/amd/1830_left.jpg',
#  '/content/eye/amd/1830_right.jpg',
#  '/content/eye/amd/1831_left.jpg',
#  '/content/eye/amd/1831_right.jpg',
#  '/content/eye/amd/1834_left.jpg',
#  '/content/eye/amd/1834_right.jpg',
#  '/content/eye/amd/1835_left.jpg',
#  '/content/eye/amd/1835_right.jpg',
#  '/content/eye/amd/1836_left.jpg',
#  '/content/eye/amd/1836_right.jpg',
#  '/content/eye/amd/1837_right.jpg',
#  '/content/eye/amd/1840_left.jpg',
#  '/content/eye/amd/1840_right.jpg',
#  '/content/eye/amd/1841_left.jpg',
#  '/content/eye/amd/1841_right.jpg',
#  '/content/eye/amd/1843_left.jpg',
#  '/content/eye/amd/1843_right.jpg',
#  '/content/eye/amd/1844_left.jpg',
#  '/content/eye/amd/1844_right.jpg',
#  '/content/eye/amd/1845_left.jpg',
#  '/content/eye/amd/1845_right.jpg',
#  '/content/eye/amd/1846_left.jpg',
#  '/content/eye/amd/1846_right.jpg',
#  '/content/eye/amd/1847_left.jpg',
#  '/content/eye/amd/1847_right.jpg',
#  '/content/eye/amd/1850_left.jpg',
#  '/content/eye/amd/1850_right.jpg',
#  '/content/eye/amd/1853_right.jpg',
#  '/content/eye/amd/1854_left.jpg',
#  '/content/eye/amd/1854_right.jpg',
#  '/content/eye/amd/1856_left.jpg',
#  '/content/eye/amd/1856_right.jpg',
#  '/content/eye/amd/1857_left.jpg',
#  '/content/eye/amd/1857_right.jpg',
#  '/content/eye/amd/1859_left.jpg',
#  '/content/eye/amd/1859_right.jpg',
#  '/content/eye/amd/1862_left.jpg',
#  '/content/eye/amd/1862_right.jpg',
#  '/content/eye/amd/1868_right.jpg',
#  '/content/eye/amd/1869_left.jpg',
#  '/content/eye/amd/1869_right.jpg',
#  '/content/eye/amd/1872_left.jpg',
#  '/content/eye/amd/1872_right.jpg',
#  '/content/eye/amd/1873_right.jpg',
#  '/content/eye/amd/1874_left.jpg',
#  '/content/eye/amd/1874_right.jpg',
#  '/content/eye/amd/1876_right.jpg',
#  '/content/eye/amd/1877_left.jpg',
#  '/content/eye/amd/1877_right.jpg',
#  '/content/eye/amd/1878_left.jpg',
#  '/content/eye/amd/1878_right.jpg',
#  '/content/eye/amd/1879_left.jpg',
#  '/content/eye/amd/1879_right.jpg',
#  '/content/eye/amd/1880_left.jpg',
#  '/content/eye/amd/1880_right.jpg',
#  '/content/eye/amd/1881_left.jpg',
#  '/content/eye/amd/1881_right.jpg',
#  '/content/eye/amd/1884_right.jpg',
#  '/content/eye/amd/1885_left.jpg',
#  '/content/eye/amd/1885_right.jpg',
#  '/content/eye/amd/1886_left.jpg',
#  '/content/eye/amd/1886_right.jpg',
#  '/content/eye/amd/1889_left.jpg',
#  '/content/eye/amd/1889_right.jpg',
#  '/content/eye/amd/1890_left.jpg',
#  '/content/eye/amd/1891_right.jpg',
#  '/content/eye/amd/1892_left.jpg',
#  '/content/eye/amd/1892_right.jpg',
#  '/content/eye/amd/1893_left.jpg',
#  '/content/eye/amd/1893_right.jpg',
#  '/content/eye/amd/1919_right.jpg',
#  '/content/eye/amd/1927_left.jpg',
#  '/content/eye/amd/1942_left.jpg',
#  '/content/eye/amd/1942_right.jpg',
#  '/content/eye/amd/2034_left.jpg',
#  '/content/eye/amd/2041_left.jpg',
#  '/content/eye/amd/2053_left.jpg',
#  '/content/eye/amd/2065_left.jpg',
#  '/content/eye/amd/2078_left.jpg',
#  '/content/eye/amd/210_left.jpg',
#  '/content/eye/amd/210_right.jpg',
#  '/content/eye/amd/212_left.jpg',
#  '/content/eye/amd/212_right.jpg',
#  '/content/eye/amd/213_right.jpg',
#  '/content/eye/amd/230_left.jpg',
#  '/content/eye/amd/230_right.jpg',
#  '/content/eye/amd/235_left.jpg',
#  '/content/eye/amd/235_right.jpg',
#  '/content/eye/amd/238_left.jpg',
#  '/content/eye/amd/238_right.jpg',
#  '/content/eye/amd/243_left.jpg',
#  '/content/eye/amd/243_right.jpg',
#  '/content/eye/amd/247_left.jpg',
#  '/content/eye/amd/247_right.jpg',
#  '/content/eye/amd/260_left.jpg',
#  '/content/eye/amd/260_right.jpg',
#  '/content/eye/amd/264_left.jpg',
#  '/content/eye/amd/265_left.jpg',
#  '/content/eye/amd/265_right.jpg',
#  '/content/eye/amd/266_left.jpg',
#  '/content/eye/amd/266_right.jpg',
#  '/content/eye/amd/270_left.jpg',
#  '/content/eye/amd/270_right.jpg',
#  '/content/eye/amd/292_left.jpg',
#  '/content/eye/amd/292_right.jpg',
#  '/content/eye/amd/311_right.jpg',
#  '/content/eye/amd/315_right.jpg',
#  '/content/eye/amd/319_left.jpg',
#  '/content/eye/amd/319_right.jpg',
#  '/content/eye/amd/321_left.jpg',
#  '/content/eye/amd/321_right.jpg',
#  '/content/eye/amd/334_left.jpg',
#  '/content/eye/amd/334_right.jpg',
#  '/content/eye/amd/359_left.jpg',
#  '/content/eye/amd/359_right.jpg',
#  '/content/eye/amd/377_left.jpg',
#  '/content/eye/amd/377_right.jpg',
#  '/content/eye/amd/3979_left.jpg',
#  '/content/eye/amd/3979_right.jpg',
#  '/content/eye/amd/4068_right.jpg',
#  '/content/eye/amd/410_left.jpg',
#  '/content/eye/amd/410_right.jpg',
#  '/content/eye/amd/419_left.jpg',
#  '/content/eye/amd/419_right.jpg',
#  '/content/eye/amd/424_left.jpg',
#  '/content/eye/amd/424_right.jpg',
#  '/content/eye/amd/4330_right.jpg',
#  '/content/eye/amd/43_left.jpg',
#  '/content/eye/amd/43_right.jpg',
#  '/content/eye/amd/447_left.jpg',
#  '/content/eye/amd/447_right.jpg',
#  '/content/eye/amd/455_left.jpg',
#  '/content/eye/amd/455_right.jpg',
#  '/content/eye/amd/464_left.jpg',
#  '/content/eye/amd/4784_left.jpg',
#  '/content/eye/amd/4784_right.jpg',
#  '/content/eye/amd/48_left.jpg',
#  '/content/eye/amd/48_right.jpg',
#  '/content/eye/amd/513_right.jpg',
#  '/content/eye/amd/514_left.jpg',
#  '/content/eye/amd/514_right.jpg',
#  '/content/eye/amd/532_left.jpg',
#  '/content/eye/amd/532_right.jpg',
#  '/content/eye/amd/53_left.jpg',
#  '/content/eye/amd/53_right.jpg',
#  '/content/eye/amd/540_right.jpg',
#  '/content/eye/amd/547_left.jpg',
#  '/content/eye/amd/547_right.jpg',
#  '/content/eye/amd/55_left.jpg',
#  '/content/eye/amd/55_right.jpg',
#  '/content/eye/amd/564_left.jpg',
#  '/content/eye/amd/564_right.jpg',
#  '/content/eye/amd/565_left.jpg',
#  '/content/eye/amd/565_right.jpg',
#  '/content/eye/amd/572_left.jpg',
#  '/content/eye/amd/572_right.jpg',
#  '/content/eye/amd/603_left.jpg',
#  '/content/eye/amd/603_right.jpg',
#  '/content/eye/amd/608_left.jpg',
#  '/content/eye/amd/608_right.jpg',
#  '/content/eye/amd/610_right.jpg',
#  '/content/eye/amd/614_left.jpg',
#  '/content/eye/amd/615_left.jpg',
#  '/content/eye/amd/615_right.jpg',
#  '/content/eye/amd/638_left.jpg',
#  '/content/eye/amd/651_left.jpg',
#  '/content/eye/amd/662_right.jpg',
#  '/content/eye/amd/681_left.jpg',
#  '/content/eye/amd/681_right.jpg',
#  '/content/eye/amd/712_left.jpg',
#  '/content/eye/amd/719_left.jpg',
#  '/content/eye/amd/719_right.jpg',
#  '/content/eye/amd/71_right.jpg',
#  '/content/eye/amd/761_left.jpg',
#  '/content/eye/amd/761_right.jpg',
#  '/content/eye/amd/775_left.jpg',
#  '/content/eye/amd/775_right.jpg',
#  '/content/eye/amd/788_left.jpg',
#  '/content/eye/amd/788_right.jpg',
#  '/content/eye/amd/808_right.jpg',
#  '/content/eye/amd/815_left.jpg',
#  '/content/eye/amd/815_right.jpg',
#  '/content/eye/amd/821_left.jpg',
#  '/content/eye/amd/821_right.jpg',
#  '/content/eye/amd/847_left.jpg',
#  '/content/eye/amd/847_right.jpg',
#  '/content/eye/amd/852_left.jpg',
#  '/content/eye/amd/852_right.jpg',
#  '/content/eye/amd/855_left.jpg',
#  '/content/eye/amd/855_right.jpg',
#  '/content/eye/amd/870_left.jpg',
#  '/content/eye/amd/870_right.jpg',
#  '/content/eye/amd/885_right.jpg',
#  '/content/eye/amd/886_right.jpg',
#  '/content/eye/amd/888_left.jpg',
#  '/content/eye/amd/888_right.jpg',
#  '/content/eye/amd/889_left.jpg',
#  '/content/eye/amd/889_right.jpg',
#  '/content/eye/amd/910_left.jpg',
#  '/content/eye/amd/910_right.jpg',
#  '/content/eye/amd/927_left.jpg',
#  '/content/eye/amd/927_right.jpg',
#  '/content/eye/amd/934_right.jpg',
#  '/content/eye/amd/938_left.jpg',
#  '/content/eye/amd/938_right.jpg',
#  '/content/eye/amd/961_left.jpg',
#  '/content/eye/amd/961_right.jpg',
#  '/content/eye/amd/971_left.jpg',
#  '/content/eye/amd/971_right.jpg',
#  '/content/eye/amd/977_left.jpg',
#  '/content/eye/amd/978_left.jpg',
#  '/content/eye/amd/992_left.jpg',
#  '/content/eye/amd/992_right.jpg',
#  '/content/eye/amd/998_left.jpg',
#  '/content/eye/amd/998_right.jpg',
#  '/content/eye/cataract/0_left.jpg',
#  '/content/eye/cataract/103_left.jpg',
#  '/content/eye/cataract/1062_right.jpg',
#  '/content/eye/cataract/1083_left.jpg',
#  '/content/eye/cataract/1084_right.jpg',
#  '/content/eye/cataract/1101_right.jpg',
#  '/content/eye/cataract/1102_left.jpg',
#  '/content/eye/cataract/1102_right.jpg',
#  '/content/eye/cataract/1115_left.jpg',
#  '/content/eye/cataract/1126_right.jpg',
#  '/content/eye/cataract/112_right.jpg',
#  '/content/eye/cataract/1144_left.jpg',
#  '/content/eye/cataract/1144_right.jpg',
#  '/content/eye/cataract/1164_left.jpg',
#  '/content/eye/cataract/1167_right.jpg',
#  '/content/eye/cataract/119_left.jpg',
#  '/content/eye/cataract/1285_left.jpg',
#  '/content/eye/cataract/1415_left.jpg',
#  '/content/eye/cataract/1415_right.jpg',
#  '/content/eye/cataract/1435_left.jpg',
#  '/content/eye/cataract/1444_left.jpg',
#  '/content/eye/cataract/1452_left.jpg',
#  '/content/eye/cataract/1454_right.jpg',
#  '/content/eye/cataract/1456_left.jpg',
#  '/content/eye/cataract/1456_right.jpg',
#  '/content/eye/cataract/1460_right.jpg',
#  '/content/eye/cataract/1468_left.jpg',
#  '/content/eye/cataract/1483_left.jpg',
#  '/content/eye/cataract/1483_right.jpg',
#  '/content/eye/cataract/1484_left.jpg',
#  '/content/eye/cataract/1484_right.jpg',
#  '/content/eye/cataract/1490_right.jpg',
#  '/content/eye/cataract/188_right.jpg',
#  '/content/eye/cataract/1968_left.jpg',
#  '/content/eye/cataract/1987_left.jpg',
#  '/content/eye/cataract/1994_left.jpg',
#  '/content/eye/cataract/2052_left.jpg',
#  '/content/eye/cataract/2052_right.jpg',
#  '/content/eye/cataract/2074_right.jpg',
#  '/content/eye/cataract/2095_right.jpg',
#  '/content/eye/cataract/2096_right.jpg',
#  '/content/eye/cataract/2097_right.jpg',
#  '/content/eye/cataract/2098_left.jpg',
#  '/content/eye/cataract/2098_right.jpg',
#  '/content/eye/cataract/2099_left.jpg',
#  '/content/eye/cataract/2100_right.jpg',
#  '/content/eye/cataract/2101_left.jpg',
#  '/content/eye/cataract/2101_right.jpg',
#  '/content/eye/cataract/2102_left.jpg',
#  '/content/eye/cataract/2102_right.jpg',
#  '/content/eye/cataract/2103_left.jpg',
#  '/content/eye/cataract/2103_right.jpg',
#  '/content/eye/cataract/2104_left.jpg',
#  '/content/eye/cataract/2104_right.jpg',
#  '/content/eye/cataract/2105_left.jpg',
#  '/content/eye/cataract/2105_right.jpg',
#  '/content/eye/cataract/2106_right.jpg',
#  '/content/eye/cataract/2107_left.jpg',
#  '/content/eye/cataract/2108_left.jpg',
#  '/content/eye/cataract/2108_right.jpg',
#  '/content/eye/cataract/2109_left.jpg',
#  '/content/eye/cataract/2109_right.jpg',
#  '/content/eye/cataract/2110_left.jpg',
#  '/content/eye/cataract/2110_right.jpg',
#  '/content/eye/cataract/2111_left.jpg',
#  '/content/eye/cataract/2112_right.jpg',
#  '/content/eye/cataract/2113_left.jpg',
#  '/content/eye/cataract/2113_right.jpg',
#  '/content/eye/cataract/2114_left.jpg',
#  '/content/eye/cataract/2114_right.jpg',
#  '/content/eye/cataract/2115_right.jpg',
#  '/content/eye/cataract/2116_left.jpg',
#  '/content/eye/cataract/2116_right.jpg',
#  '/content/eye/cataract/2117_left.jpg',
#  '/content/eye/cataract/2118_right.jpg',
#  '/content/eye/cataract/2119_right.jpg',
#  '/content/eye/cataract/2120_left.jpg',
#  '/content/eye/cataract/2120_right.jpg',
#  '/content/eye/cataract/2121_left.jpg',
#  '/content/eye/cataract/2122_left.jpg',
#  '/content/eye/cataract/2122_right.jpg',
#  '/content/eye/cataract/2123_left.jpg',
#  '/content/eye/cataract/2124_left.jpg',
#  '/content/eye/cataract/2125_left.jpg',
#  '/content/eye/cataract/2126_left.jpg',
#  '/content/eye/cataract/2126_right.jpg',
#  '/content/eye/cataract/2127_left.jpg',
#  '/content/eye/cataract/2127_right.jpg',
#  '/content/eye/cataract/2128_left.jpg',
#  '/content/eye/cataract/2128_right.jpg',
#  '/content/eye/cataract/2129_left.jpg',
#  '/content/eye/cataract/2129_right.jpg',
#  '/content/eye/cataract/2130_left.jpg',
#  '/content/eye/cataract/2130_right.jpg',
#  '/content/eye/cataract/2132_left.jpg',
#  '/content/eye/cataract/2133_left.jpg',
#  '/content/eye/cataract/2133_right.jpg',
#  '/content/eye/cataract/2134_left.jpg',
#  '/content/eye/cataract/2134_right.jpg',
#  '/content/eye/cataract/2135_left.jpg',
#  '/content/eye/cataract/2135_right.jpg',
#  '/content/eye/cataract/2136_left.jpg',
#  '/content/eye/cataract/2137_left.jpg',
#  '/content/eye/cataract/2137_right.jpg',
#  '/content/eye/cataract/2138_left.jpg',
#  '/content/eye/cataract/2138_right.jpg',
#  '/content/eye/cataract/2139_right.jpg',
#  '/content/eye/cataract/2140_left.jpg',
#  '/content/eye/cataract/2140_right.jpg',
#  '/content/eye/cataract/2141_right.jpg',
#  '/content/eye/cataract/2142_left.jpg',
#  '/content/eye/cataract/2142_right.jpg',
#  '/content/eye/cataract/2143_right.jpg',
#  '/content/eye/cataract/2144_left.jpg',
#  '/content/eye/cataract/2144_right.jpg',
#  '/content/eye/cataract/2145_left.jpg',
#  '/content/eye/cataract/2146_left.jpg',
#  '/content/eye/cataract/2146_right.jpg',
#  '/content/eye/cataract/2147_left.jpg',
#  '/content/eye/cataract/2149_right.jpg',
#  '/content/eye/cataract/2150_left.jpg',
#  '/content/eye/cataract/2150_right.jpg',
#  '/content/eye/cataract/2151_left.jpg',
#  '/content/eye/cataract/2151_right.jpg',
#  '/content/eye/cataract/2152_left.jpg',
#  '/content/eye/cataract/2153_left.jpg',
#  '/content/eye/cataract/2153_right.jpg',
#  '/content/eye/cataract/2154_left.jpg',
#  '/content/eye/cataract/2155_left.jpg',
#  '/content/eye/cataract/2155_right.jpg',
#  '/content/eye/cataract/2156_left.jpg',
#  '/content/eye/cataract/2157_left.jpg',
#  '/content/eye/cataract/2157_right.jpg',
#  '/content/eye/cataract/2158_left.jpg',
#  '/content/eye/cataract/2158_right.jpg',
#  '/content/eye/cataract/2159_left.jpg',
#  '/content/eye/cataract/2160_right.jpg',
#  '/content/eye/cataract/2161_right.jpg',
#  '/content/eye/cataract/2162_right.jpg',
#  '/content/eye/cataract/2163_left.jpg',
#  '/content/eye/cataract/2163_right.jpg',
#  '/content/eye/cataract/2164_left.jpg',
#  '/content/eye/cataract/2164_right.jpg',
#  '/content/eye/cataract/2165_right.jpg',
#  '/content/eye/cataract/2166_left.jpg',
#  '/content/eye/cataract/2167_left.jpg',
#  '/content/eye/cataract/2167_right.jpg',
#  '/content/eye/cataract/2168_left.jpg',
#  '/content/eye/cataract/2168_right.jpg',
#  '/content/eye/cataract/2169_left.jpg',
#  '/content/eye/cataract/2169_right.jpg',
#  '/content/eye/cataract/2170_left.jpg',
#  '/content/eye/cataract/2170_right.jpg',
#  '/content/eye/cataract/2171_left.jpg',
#  '/content/eye/cataract/2172_left.jpg',
#  '/content/eye/cataract/2173_right.jpg',
#  '/content/eye/cataract/2174_right.jpg',
#  '/content/eye/cataract/2175_left.jpg',
#  '/content/eye/cataract/2176_left.jpg',
#  '/content/eye/cataract/2176_right.jpg',
#  '/content/eye/cataract/2177_right.jpg',
#  '/content/eye/cataract/2178_left.jpg',
#  '/content/eye/cataract/2178_right.jpg',
#  '/content/eye/cataract/2179_left.jpg',
#  '/content/eye/cataract/2179_right.jpg',
#  '/content/eye/cataract/2180_left.jpg',
#  '/content/eye/cataract/2180_right.jpg',
#  '/content/eye/cataract/2181_left.jpg',
#  '/content/eye/cataract/2181_right.jpg',
#  '/content/eye/cataract/2182_left.jpg',
#  '/content/eye/cataract/2182_right.jpg',
#  '/content/eye/cataract/2183_left.jpg',
#  '/content/eye/cataract/2183_right.jpg',
#  '/content/eye/cataract/2184_left.jpg',
#  '/content/eye/cataract/2184_right.jpg',
#  '/content/eye/cataract/2185_left.jpg',
#  '/content/eye/cataract/2187_right.jpg',
#  '/content/eye/cataract/2189_left.jpg',
#  '/content/eye/cataract/2189_right.jpg',
#  '/content/eye/cataract/218_right.jpg',
#  '/content/eye/cataract/2190_right.jpg',
#  '/content/eye/cataract/2191_right.jpg',
#  '/content/eye/cataract/2192_left.jpg',
#  '/content/eye/cataract/2192_right.jpg',
#  '/content/eye/cataract/2193_right.jpg',
#  '/content/eye/cataract/2194_left.jpg',
#  '/content/eye/cataract/2194_right.jpg',
#  '/content/eye/cataract/2195_left.jpg',
#  '/content/eye/cataract/2195_right.jpg',
#  '/content/eye/cataract/2196_right.jpg',
#  '/content/eye/cataract/2197_right.jpg',
#  '/content/eye/cataract/2198_left.jpg',
#  '/content/eye/cataract/2198_right.jpg',
#  '/content/eye/cataract/2199_left.jpg',
#  '/content/eye/cataract/2200_left.jpg',
#  '/content/eye/cataract/2201_right.jpg',
#  '/content/eye/cataract/2203_left.jpg',
#  '/content/eye/cataract/2203_right.jpg',
#  '/content/eye/cataract/2204_left.jpg',
#  '/content/eye/cataract/2205_right.jpg',
#  '/content/eye/cataract/2206_left.jpg',
#  '/content/eye/cataract/2206_right.jpg',
#  '/content/eye/cataract/2207_left.jpg',
#  '/content/eye/cataract/2207_right.jpg',
#  '/content/eye/cataract/2208_right.jpg',
#  '/content/eye/cataract/2209_left.jpg',
#  '/content/eye/cataract/2209_right.jpg',
#  '/content/eye/cataract/2210_left.jpg',
#  '/content/eye/cataract/2210_right.jpg',
#  '/content/eye/cataract/2211_left.jpg',
#  '/content/eye/cataract/2211_right.jpg',
#  '/content/eye/cataract/2212_left.jpg',
#  '/content/eye/cataract/2212_right.jpg',
#  '/content/eye/cataract/2213_left.jpg',
#  '/content/eye/cataract/2213_right.jpg',
#  '/content/eye/cataract/2214_left.jpg',
#  '/content/eye/cataract/2214_right.jpg',
#  '/content/eye/cataract/2215_left.jpg',
#  '/content/eye/cataract/2216_left.jpg',
#  '/content/eye/cataract/2216_right.jpg',
#  '/content/eye/cataract/2217_left.jpg',
#  '/content/eye/cataract/2217_right.jpg',
#  '/content/eye/cataract/2218_right.jpg',
#  '/content/eye/cataract/2219_left.jpg',
#  '/content/eye/cataract/2219_right.jpg',
#  '/content/eye/cataract/2220_right.jpg',
#  '/content/eye/cataract/2221_left.jpg',
#  '/content/eye/cataract/2221_right.jpg',
#  '/content/eye/cataract/2222_left.jpg',
#  '/content/eye/cataract/2223_left.jpg',
#  '/content/eye/cataract/2223_right.jpg',
#  '/content/eye/cataract/2225_left.jpg',
#  '/content/eye/cataract/2225_right.jpg',
#  '/content/eye/cataract/2226_left.jpg',
#  '/content/eye/cataract/2226_right.jpg',
#  '/content/eye/cataract/2227_left.jpg',
#  '/content/eye/cataract/2227_right.jpg',
#  '/content/eye/cataract/2228_right.jpg',
#  '/content/eye/cataract/2229_left.jpg',
#  '/content/eye/cataract/2229_right.jpg',
#  '/content/eye/cataract/2230_left.jpg',
#  '/content/eye/cataract/2230_right.jpg',
#  '/content/eye/cataract/2231_left.jpg',
#  '/content/eye/cataract/2231_right.jpg',
#  '/content/eye/cataract/2232_left.jpg',
#  '/content/eye/cataract/2232_right.jpg',
#  '/content/eye/cataract/2233_left.jpg',
#  '/content/eye/cataract/2233_right.jpg',
#  '/content/eye/cataract/2234_left.jpg',
#  '/content/eye/cataract/2234_right.jpg',
#  '/content/eye/cataract/2235_left.jpg',
#  '/content/eye/cataract/2236_left.jpg',
#  '/content/eye/cataract/2236_right.jpg',
#  '/content/eye/cataract/2237_right.jpg',
#  '/content/eye/cataract/2239_left.jpg',
#  '/content/eye/cataract/2239_right.jpg',
#  '/content/eye/cataract/2240_left.jpg',
#  '/content/eye/cataract/2240_right.jpg',
#  '/content/eye/cataract/2241_left.jpg',
#  '/content/eye/cataract/2242_left.jpg',
#  '/content/eye/cataract/2242_right.jpg',
#  '/content/eye/cataract/2243_left.jpg',
#  '/content/eye/cataract/2243_right.jpg',
#  '/content/eye/cataract/2244_left.jpg',
#  '/content/eye/cataract/2244_right.jpg',
#  '/content/eye/cataract/2246_left.jpg',
#  '/content/eye/cataract/2246_right.jpg',
#  '/content/eye/cataract/2247_left.jpg',
#  '/content/eye/cataract/2247_right.jpg',
#  '/content/eye/cataract/2248_left.jpg',
#  '/content/eye/cataract/2248_right.jpg',
#  '/content/eye/cataract/2251_left.jpg',
#  '/content/eye/cataract/2251_right.jpg',
#  '/content/eye/cataract/2262_left.jpg',
#  '/content/eye/cataract/2282_right.jpg',
#  '/content/eye/cataract/24_right.jpg',
#  '/content/eye/cataract/254_left.jpg',
#  '/content/eye/cataract/294_left.jpg',
#  '/content/eye/cataract/330_left.jpg',
#  '/content/eye/cataract/345_right.jpg',
#  '/content/eye/cataract/354_right.jpg',
#  '/content/eye/cataract/4435_right.jpg',
#  '/content/eye/cataract/448_left.jpg',
#  '/content/eye/cataract/465_left.jpg',
#  '/content/eye/cataract/477_left.jpg',
#  '/content/eye/cataract/477_right.jpg',
#  '/content/eye/cataract/553_left.jpg',
#  '/content/eye/cataract/553_right.jpg',
#  '/content/eye/cataract/560_left.jpg',
#  '/content/eye/cataract/560_right.jpg',
#  '/content/eye/cataract/594_left.jpg',
#  '/content/eye/cataract/611_left.jpg',
#  '/content/eye/cataract/625_left.jpg',
#  '/content/eye/cataract/625_right.jpg',
#  '/content/eye/cataract/629_left.jpg',
#  '/content/eye/cataract/691_left.jpg',
#  '/content/eye/cataract/726_left.jpg',
#  '/content/eye/cataract/726_right.jpg',
#  '/content/eye/cataract/750_left.jpg',
#  '/content/eye/cataract/769_right.jpg',
#  '/content/eye/cataract/809_left.jpg',
#  '/content/eye/cataract/81_left.jpg',
#  '/content/eye/cataract/81_right.jpg',
#  '/content/eye/cataract/820_left.jpg',
#  '/content/eye/cataract/824_left.jpg',
#  '/content/eye/cataract/874_left.jpg',
#  '/content/eye/cataract/907_left.jpg',
#  '/content/eye/cataract/949_right.jpg',
#  '/content/eye/cataract/955_right.jpg',
#  '/content/eye/cataract/970_left.jpg',
#  '/content/eye/cataract/970_right.jpg',
#  '/content/eye/cataract/999_left.jpg',
#  '/content/eye/cataract/999_right.jpg',
#  '/content/eye/diabetes/1020_right.jpg',
#  '/content/eye/diabetes/1022_left.jpg',
#  '/content/eye/diabetes/1022_right.jpg',
#  '/content/eye/diabetes/1024_right.jpg',
#  '/content/eye/diabetes/1035_right.jpg',
#  '/content/eye/diabetes/1065_right.jpg',
#  '/content/eye/diabetes/1068_left.jpg',
#  '/content/eye/diabetes/1068_right.jpg',
#  '/content/eye/diabetes/1071_left.jpg',
#  '/content/eye/diabetes/1071_right.jpg',
#  '/content/eye/diabetes/107_right.jpg',
#  '/content/eye/diabetes/1082_left.jpg',
#  '/content/eye/diabetes/1082_right.jpg',
#  '/content/eye/diabetes/1083_left.jpg',
#  '/content/eye/diabetes/1083_right.jpg',
#  '/content/eye/diabetes/1084_left.jpg',
#  '/content/eye/diabetes/1084_right.jpg',
#  '/content/eye/diabetes/108_left.jpg',
#  '/content/eye/diabetes/1094_left.jpg',
#  '/content/eye/diabetes/1094_right.jpg',
#  '/content/eye/diabetes/1106_left.jpg',
#  '/content/eye/diabetes/1106_right.jpg',
#  '/content/eye/diabetes/1113_right.jpg',
#  '/content/eye/diabetes/111_left.jpg',
#  '/content/eye/diabetes/111_right.jpg',
#  '/content/eye/diabetes/1136_left.jpg',
#  '/content/eye/diabetes/1136_right.jpg',
#  '/content/eye/diabetes/1138_left.jpg',
#  '/content/eye/diabetes/1138_right.jpg',
#  '/content/eye/diabetes/113_left.jpg',
#  '/content/eye/diabetes/1144_right.jpg',
#  '/content/eye/diabetes/1147_left.jpg',
#  '/content/eye/diabetes/1147_right.jpg',
#  '/content/eye/diabetes/1152_left.jpg',
#  '/content/eye/diabetes/1152_right.jpg',
#  '/content/eye/diabetes/1153_left.jpg',
#  '/content/eye/diabetes/1153_right.jpg',
#  '/content/eye/diabetes/1157_left.jpg',
#  '/content/eye/diabetes/1157_right.jpg',
#  '/content/eye/diabetes/1167_left.jpg',
#  '/content/eye/diabetes/1167_right.jpg',
#  '/content/eye/diabetes/118_left.jpg',
#  '/content/eye/diabetes/118_right.jpg',
#  '/content/eye/diabetes/1191_left.jpg',
#  '/content/eye/diabetes/11_left.jpg',
#  '/content/eye/diabetes/11_right.jpg',
#  '/content/eye/diabetes/1205_left.jpg',
#  '/content/eye/diabetes/1205_right.jpg',
#  '/content/eye/diabetes/1206_left.jpg',
#  '/content/eye/diabetes/120_left.jpg',
#  '/content/eye/diabetes/120_right.jpg',
#  '/content/eye/diabetes/1213_left.jpg',
#  '/content/eye/diabetes/1213_right.jpg',
#  '/content/eye/diabetes/121_left.jpg',
#  '/content/eye/diabetes/1225_left.jpg',
#  '/content/eye/diabetes/1225_right.jpg',
#  '/content/eye/diabetes/1228_left.jpg',
#  '/content/eye/diabetes/1228_right.jpg',
#  '/content/eye/diabetes/1230_left.jpg',
#  '/content/eye/diabetes/1230_right.jpg',
#  '/content/eye/diabetes/1238_left.jpg',
#  '/content/eye/diabetes/1238_right.jpg',
#  '/content/eye/diabetes/123_right.jpg',
#  '/content/eye/diabetes/1251_left.jpg',
#  '/content/eye/diabetes/1251_right.jpg',
#  '/content/eye/diabetes/1279_left.jpg',
#  '/content/eye/diabetes/1279_right.jpg',
#  '/content/eye/diabetes/127_left.jpg',
#  '/content/eye/diabetes/127_right.jpg',
#  '/content/eye/diabetes/1281_left.jpg',
#  '/content/eye/diabetes/1281_right.jpg',
#  '/content/eye/diabetes/1285_right.jpg',
#  '/content/eye/diabetes/1286_left.jpg',
#  '/content/eye/diabetes/1286_right.jpg',
#  '/content/eye/diabetes/1289_left.jpg',
#  '/content/eye/diabetes/1289_right.jpg',
#  '/content/eye/diabetes/1302_left.jpg',
#  '/content/eye/diabetes/1302_right.jpg',
#  '/content/eye/diabetes/130_left.jpg',
#  '/content/eye/diabetes/130_right.jpg',
#  '/content/eye/diabetes/133_left.jpg',
#  '/content/eye/diabetes/133_right.jpg',
#  '/content/eye/diabetes/1364_right.jpg',
#  '/content/eye/diabetes/1366_left.jpg',
#  '/content/eye/diabetes/1366_right.jpg',
#  '/content/eye/diabetes/137_right.jpg',
#  '/content/eye/diabetes/1388_left.jpg',
#  '/content/eye/diabetes/139_left.jpg',
#  '/content/eye/diabetes/139_right.jpg',
#  '/content/eye/diabetes/1402_left.jpg',
#  '/content/eye/diabetes/1402_right.jpg',
#  '/content/eye/diabetes/1406_left.jpg',
#  '/content/eye/diabetes/1409_left.jpg',
#  '/content/eye/diabetes/1409_right.jpg',
#  '/content/eye/diabetes/1410_right.jpg',
#  '/content/eye/diabetes/1413_left.jpg',
#  '/content/eye/diabetes/1428_left.jpg',
#  '/content/eye/diabetes/1434_left.jpg',
#  '/content/eye/diabetes/1434_right.jpg',
#  '/content/eye/diabetes/1442_left.jpg',
#  '/content/eye/diabetes/1474_left.jpg',
#  '/content/eye/diabetes/1482_left.jpg',
#  '/content/eye/diabetes/1482_right.jpg',
#  '/content/eye/diabetes/1488_right.jpg',
#  '/content/eye/diabetes/148_right.jpg',
#  '/content/eye/diabetes/1496_left.jpg',
#  '/content/eye/diabetes/1496_right.jpg',
#  '/content/eye/diabetes/151_right.jpg',
#  '/content/eye/diabetes/1543_left.jpg',
#  '/content/eye/diabetes/157_left.jpg',
#  '/content/eye/diabetes/157_right.jpg',
#  '/content/eye/diabetes/159_left.jpg',
#  '/content/eye/diabetes/161_left.jpg',
#  '/content/eye/diabetes/161_right.jpg',
#  '/content/eye/diabetes/163_left.jpg',
#  '/content/eye/diabetes/1657_right.jpg',
#  '/content/eye/diabetes/1660_left.jpg',
#  '/content/eye/diabetes/1660_right.jpg',
#  '/content/eye/diabetes/1674_left.jpg',
#  '/content/eye/diabetes/169_left.jpg',
#  '/content/eye/diabetes/169_right.jpg',
#  '/content/eye/diabetes/1706_right.jpg',
#  '/content/eye/diabetes/1718_left.jpg',
#  '/content/eye/diabetes/1718_right.jpg',
#  '/content/eye/diabetes/171_left.jpg',
#  '/content/eye/diabetes/1731_right.jpg',
#  '/content/eye/diabetes/175_right.jpg',
#  '/content/eye/diabetes/176_left.jpg',
#  '/content/eye/diabetes/176_right.jpg',
#  '/content/eye/diabetes/177_left.jpg',
#  '/content/eye/diabetes/177_right.jpg',
#  '/content/eye/diabetes/1838_left.jpg',
#  '/content/eye/diabetes/1838_right.jpg',
#  '/content/eye/diabetes/184_right.jpg',
#  '/content/eye/diabetes/186_left.jpg',
#  '/content/eye/diabetes/186_right.jpg',
#  '/content/eye/diabetes/188_left.jpg',
#  '/content/eye/diabetes/193_right.jpg',
#  '/content/eye/diabetes/1942_left.jpg',
#  '/content/eye/diabetes/1942_right.jpg',
#  '/content/eye/diabetes/195_left.jpg',
#  '/content/eye/diabetes/195_right.jpg',
#  '/content/eye/diabetes/1963_left.jpg',
#  '/content/eye/diabetes/1965_left.jpg',
#  '/content/eye/diabetes/1965_right.jpg',
#  '/content/eye/diabetes/1971_right.jpg',
#  '/content/eye/diabetes/1974_left.jpg',
#  '/content/eye/diabetes/1978_left.jpg',
#  '/content/eye/diabetes/1985_left.jpg',
#  '/content/eye/diabetes/1994_left.jpg',
#  '/content/eye/diabetes/1994_right.jpg',
#  '/content/eye/diabetes/199_right.jpg',
#  '/content/eye/diabetes/19_left.jpg',
#  '/content/eye/diabetes/19_right.jpg',
#  '/content/eye/diabetes/2010_left.jpg',
#  '/content/eye/diabetes/201_left.jpg',
#  '/content/eye/diabetes/202_right.jpg',
#  '/content/eye/diabetes/2030_right.jpg',
#  '/content/eye/diabetes/2032_left.jpg',
#  '/content/eye/diabetes/2032_right.jpg',
#  '/content/eye/diabetes/203_left.jpg',
#  '/content/eye/diabetes/2053_right.jpg',
#  '/content/eye/diabetes/2063_right.jpg',
#  '/content/eye/diabetes/2064_left.jpg',
#  '/content/eye/diabetes/2064_right.jpg',
#  '/content/eye/diabetes/206_left.jpg',
#  '/content/eye/diabetes/206_right.jpg',
#  '/content/eye/diabetes/2078_left.jpg',
#  '/content/eye/diabetes/2078_right.jpg',
#  '/content/eye/diabetes/207_left.jpg',
#  '/content/eye/diabetes/207_right.jpg',
#  '/content/eye/diabetes/2096_left.jpg',
#  '/content/eye/diabetes/2099_right.jpg',
#  '/content/eye/diabetes/209_left.jpg',
#  '/content/eye/diabetes/209_right.jpg',
#  '/content/eye/diabetes/2100_left.jpg',
#  '/content/eye/diabetes/2100_right.jpg',
#  '/content/eye/diabetes/2103_left.jpg',
#  '/content/eye/diabetes/2107_right.jpg',
#  '/content/eye/diabetes/2115_left.jpg',
#  '/content/eye/diabetes/2117_right.jpg',
#  '/content/eye/diabetes/211_left.jpg',
#  '/content/eye/diabetes/211_right.jpg',
#  '/content/eye/diabetes/212_left.jpg',
#  '/content/eye/diabetes/212_right.jpg',
#  '/content/eye/diabetes/2141_left.jpg',
#  '/content/eye/diabetes/2156_right.jpg',
#  '/content/eye/diabetes/2161_left.jpg',
#  '/content/eye/diabetes/2164_left.jpg',
#  '/content/eye/diabetes/2165_left.jpg',
#  '/content/eye/diabetes/2166_right.jpg',
#  '/content/eye/diabetes/2168_right.jpg',
#  '/content/eye/diabetes/216_left.jpg',
#  '/content/eye/diabetes/217_right.jpg',
#  '/content/eye/diabetes/2200_right.jpg',
#  '/content/eye/diabetes/2201_left.jpg',
#  '/content/eye/diabetes/221_left.jpg',
#  '/content/eye/diabetes/221_right.jpg',
#  '/content/eye/diabetes/2220_left.jpg',
#  '/content/eye/diabetes/2226_right.jpg',
#  '/content/eye/diabetes/2228_left.jpg',
#  '/content/eye/diabetes/2234_right.jpg',
#  '/content/eye/diabetes/223_left.jpg',
#  '/content/eye/diabetes/223_right.jpg',
#  '/content/eye/diabetes/224_left.jpg',
#  '/content/eye/diabetes/224_right.jpg',
#  '/content/eye/diabetes/225_right.jpg',
#  '/content/eye/diabetes/2262_right.jpg',
#  '/content/eye/diabetes/2282_left.jpg',
#  '/content/eye/diabetes/229_left.jpg',
#  '/content/eye/diabetes/229_right.jpg',
#  '/content/eye/diabetes/22_left.jpg',
#  '/content/eye/diabetes/22_right.jpg',
#  '/content/eye/diabetes/231_left.jpg',
#  '/content/eye/diabetes/234_left.jpg',
#  '/content/eye/diabetes/234_right.jpg',
#  '/content/eye/diabetes/249_left.jpg',
#  '/content/eye/diabetes/249_right.jpg',
#  '/content/eye/diabetes/250_left.jpg',
#  '/content/eye/diabetes/251_left.jpg',
#  '/content/eye/diabetes/251_right.jpg',
#  '/content/eye/diabetes/257_left.jpg',
#  '/content/eye/diabetes/257_right.jpg',
#  '/content/eye/diabetes/262_left.jpg',
#  '/content/eye/diabetes/262_right.jpg',
#  '/content/eye/diabetes/263_left.jpg',
#  '/content/eye/diabetes/267_left.jpg',
#  '/content/eye/diabetes/268_left.jpg',
#  '/content/eye/diabetes/268_right.jpg',
#  '/content/eye/diabetes/26_left.jpg',
#  '/content/eye/diabetes/26_right.jpg',
#  '/content/eye/diabetes/274_left.jpg',
#  '/content/eye/diabetes/274_right.jpg',
#  '/content/eye/diabetes/279_left.jpg',
#  '/content/eye/diabetes/27_right.jpg',
#  '/content/eye/diabetes/280_left.jpg',
#  '/content/eye/diabetes/280_right.jpg',
#  '/content/eye/diabetes/281_left.jpg',
#  '/content/eye/diabetes/281_right.jpg',
#  '/content/eye/diabetes/282_left.jpg',
#  '/content/eye/diabetes/284_left.jpg',
#  '/content/eye/diabetes/284_right.jpg',
#  '/content/eye/diabetes/288_left.jpg',
#  '/content/eye/diabetes/288_right.jpg',
#  '/content/eye/diabetes/289_left.jpg',
#  '/content/eye/diabetes/289_right.jpg',
#  '/content/eye/diabetes/291_right.jpg',
#  '/content/eye/diabetes/296_left.jpg',
#  '/content/eye/diabetes/296_right.jpg',
#  '/content/eye/diabetes/299_left.jpg',
#  '/content/eye/diabetes/299_right.jpg',
#  '/content/eye/diabetes/2_left.jpg',
#  '/content/eye/diabetes/2_right.jpg',
#  '/content/eye/diabetes/304_left.jpg',
#  '/content/eye/diabetes/304_right.jpg',
#  '/content/eye/diabetes/305_left.jpg',
#  '/content/eye/diabetes/308_left.jpg',
#  '/content/eye/diabetes/309_left.jpg',
#  '/content/eye/diabetes/309_right.jpg',
#  '/content/eye/diabetes/311_left.jpg',
#  '/content/eye/diabetes/312_right.jpg',
#  '/content/eye/diabetes/314_left.jpg',
#  '/content/eye/diabetes/320_left.jpg',
#  '/content/eye/diabetes/324_left.jpg',
#  '/content/eye/diabetes/324_right.jpg',
#  '/content/eye/diabetes/327_left.jpg',
#  '/content/eye/diabetes/327_right.jpg',
#  '/content/eye/diabetes/328_left.jpg',
#  '/content/eye/diabetes/328_right.jpg',
#  '/content/eye/diabetes/338_left.jpg',
#  '/content/eye/diabetes/338_right.jpg',
#  '/content/eye/diabetes/340_left.jpg',
#  '/content/eye/diabetes/341_left.jpg',
#  '/content/eye/diabetes/341_right.jpg',
#  '/content/eye/diabetes/342_left.jpg',
#  '/content/eye/diabetes/342_right.jpg',
#  '/content/eye/diabetes/348_left.jpg',
#  '/content/eye/diabetes/348_right.jpg',
#  '/content/eye/diabetes/358_left.jpg',
#  '/content/eye/diabetes/358_right.jpg',
#  '/content/eye/diabetes/360_right.jpg',
#  '/content/eye/diabetes/361_left.jpg',
#  '/content/eye/diabetes/361_right.jpg',
#  '/content/eye/diabetes/362_right.jpg',
#  '/content/eye/diabetes/367_right.jpg',
#  '/content/eye/diabetes/368_left.jpg',
#  '/content/eye/diabetes/369_left.jpg',
#  '/content/eye/diabetes/369_right.jpg',
#  '/content/eye/diabetes/375_left.jpg',
#  '/content/eye/diabetes/375_right.jpg',
#  '/content/eye/diabetes/376_right.jpg',
#  '/content/eye/diabetes/378_right.jpg',
#  '/content/eye/diabetes/37_left.jpg',
#  '/content/eye/diabetes/380_left.jpg',
#  '/content/eye/diabetes/383_left.jpg',
#  '/content/eye/diabetes/383_right.jpg',
#  '/content/eye/diabetes/386_left.jpg',
#  '/content/eye/diabetes/386_right.jpg',
#  '/content/eye/diabetes/387_left.jpg',
#  '/content/eye/diabetes/387_right.jpg',
#  '/content/eye/diabetes/391_right.jpg',
#  '/content/eye/diabetes/392_right.jpg',
#  '/content/eye/diabetes/3932_left.jpg',
#  '/content/eye/diabetes/3932_right.jpg',
#  '/content/eye/diabetes/3934_left.jpg',
#  '/content/eye/diabetes/3934_right.jpg',
#  '/content/eye/diabetes/3935_right.jpg',
#  '/content/eye/diabetes/3936_left.jpg',
#  '/content/eye/diabetes/3936_right.jpg',
#  '/content/eye/diabetes/3937_right.jpg',
#  '/content/eye/diabetes/3938_left.jpg',
#  '/content/eye/diabetes/3938_right.jpg',
#  '/content/eye/diabetes/3939_left.jpg',
#  '/content/eye/diabetes/3939_right.jpg',
#  '/content/eye/diabetes/3940_right.jpg',
#  '/content/eye/diabetes/3941_left.jpg',
#  '/content/eye/diabetes/3943_left.jpg',
#  '/content/eye/diabetes/3944_left.jpg',
#  '/content/eye/diabetes/3944_right.jpg',
#  '/content/eye/diabetes/3945_left.jpg',
#  '/content/eye/diabetes/3945_right.jpg',
#  '/content/eye/diabetes/3946_left.jpg',
#  '/content/eye/diabetes/3946_right.jpg',
#  '/content/eye/diabetes/3947_left.jpg',
#  '/content/eye/diabetes/3948_left.jpg',
#  '/content/eye/diabetes/3948_right.jpg',
#  '/content/eye/diabetes/3949_right.jpg',
#  '/content/eye/diabetes/3950_left.jpg',
#  '/content/eye/diabetes/3950_right.jpg',
#  '/content/eye/diabetes/3951_left.jpg',
#  '/content/eye/diabetes/3952_left.jpg',
#  '/content/eye/diabetes/3952_right.jpg',
#  '/content/eye/diabetes/3953_left.jpg',
#  '/content/eye/diabetes/3953_right.jpg',
#  '/content/eye/diabetes/3954_left.jpg',
#  '/content/eye/diabetes/3955_left.jpg',
#  '/content/eye/diabetes/3955_right.jpg',
#  '/content/eye/diabetes/3956_left.jpg',
#  '/content/eye/diabetes/3956_right.jpg',
#  '/content/eye/diabetes/3957_left.jpg',
#  '/content/eye/diabetes/3957_right.jpg',
#  '/content/eye/diabetes/3958_left.jpg',
#  '/content/eye/diabetes/3958_right.jpg',
#  '/content/eye/diabetes/3960_left.jpg',
#  '/content/eye/diabetes/3961_right.jpg',
#  '/content/eye/diabetes/3962_left.jpg',
#  '/content/eye/diabetes/3962_right.jpg',
#  '/content/eye/diabetes/3965_left.jpg',
#  '/content/eye/diabetes/3965_right.jpg',
#  '/content/eye/diabetes/3966_left.jpg',
#  '/content/eye/diabetes/3966_right.jpg',
#  '/content/eye/diabetes/3968_left.jpg',
#  '/content/eye/diabetes/3968_right.jpg',
#  '/content/eye/diabetes/3969_left.jpg',
#  '/content/eye/diabetes/3969_right.jpg',
#  '/content/eye/diabetes/3970_right.jpg',
#  '/content/eye/diabetes/3971_left.jpg',
#  '/content/eye/diabetes/3971_right.jpg',
#  '/content/eye/diabetes/3972_left.jpg',
#  '/content/eye/diabetes/3972_right.jpg',
#  '/content/eye/diabetes/3973_left.jpg',
#  '/content/eye/diabetes/3973_right.jpg',
#  '/content/eye/diabetes/3976_left.jpg',
#  '/content/eye/diabetes/3976_right.jpg',
#  '/content/eye/diabetes/3977_left.jpg',
#  '/content/eye/diabetes/3978_left.jpg',
#  '/content/eye/diabetes/3978_right.jpg',
#  '/content/eye/diabetes/3979_left.jpg',
#  '/content/eye/diabetes/3979_right.jpg',
#  '/content/eye/diabetes/397_right.jpg',
#  '/content/eye/diabetes/3980_left.jpg',
#  '/content/eye/diabetes/3980_right.jpg',
#  '/content/eye/diabetes/3981_left.jpg',
#  '/content/eye/diabetes/3981_right.jpg',
#  '/content/eye/diabetes/3982_left.jpg',
#  '/content/eye/diabetes/3982_right.jpg',
#  '/content/eye/diabetes/3983_right.jpg',
#  '/content/eye/diabetes/3984_left.jpg',
#  '/content/eye/diabetes/3985_left.jpg',
#  '/content/eye/diabetes/3985_right.jpg',
#  '/content/eye/diabetes/3986_left.jpg',
#  '/content/eye/diabetes/3986_right.jpg',
#  '/content/eye/diabetes/3987_left.jpg',
#  '/content/eye/diabetes/3987_right.jpg',
#  '/content/eye/diabetes/398_right.jpg',
#  '/content/eye/diabetes/3990_left.jpg',
#  '/content/eye/diabetes/3990_right.jpg',
#  '/content/eye/diabetes/3991_left.jpg',
#  '/content/eye/diabetes/3991_right.jpg',
#  '/content/eye/diabetes/3992_left.jpg',
#  '/content/eye/diabetes/3992_right.jpg',
#  '/content/eye/diabetes/3993_left.jpg',
#  '/content/eye/diabetes/3993_right.jpg',
#  '/content/eye/diabetes/3994_left.jpg',
#  '/content/eye/diabetes/3994_right.jpg',
#  '/content/eye/diabetes/3995_left.jpg',
#  '/content/eye/diabetes/3995_right.jpg',
#  '/content/eye/diabetes/3996_left.jpg',
#  '/content/eye/diabetes/3996_right.jpg',
#  '/content/eye/diabetes/3997_left.jpg',
#  '/content/eye/diabetes/3997_right.jpg',
#  '/content/eye/diabetes/3998_left.jpg',
#  '/content/eye/diabetes/3999_left.jpg',
#  '/content/eye/diabetes/399_left.jpg',
#  '/content/eye/diabetes/4001_left.jpg',
#  '/content/eye/diabetes/4001_right.jpg',
#  '/content/eye/diabetes/4002_left.jpg',
#  ...]

# %%
images = []
labels = []

for i in imagePaths:
  image = cv2.imread(i)
  image = cv2.resize(image,(64,64))
  images.append(image)
  label = i.split(os.path.sep)[-2]
  labels.append(label)

# %%
plt.imshow(images[2])

# %%
images = np.array(images , dtype='float') / 255.0
labels = np.array(labels)

# %%
images.shape
# Out:
# (7524, 64, 64, 3)

# %%
labels
# Out:
# array(['amd', 'amd', 'amd', ..., 'other', 'other', 'other'], dtype='<U12')

# %%
lb = LabelBinarizer()

# %%
(trainX,testX,trainY,testY) = train_test_split(images,labels,test_size=0.15,random_state=42)

# %%
print(type(trainX))
print(trainX.shape)
print(type(trainY))
print(trainY.shape)
print(type(testX))
print(testX.shape)
print(type(testY))
print(testY.shape)
# Out:
# <class 'numpy.ndarray'>
# (6395, 64, 64, 3)
# <class 'numpy.ndarray'>
# (6395,)
# <class 'numpy.ndarray'>
# (1129, 64, 64, 3)
# <class 'numpy.ndarray'>
# (1129,)

# %%
trainY = lb.fit_transform(trainY)
testY = lb.transform(testY)

# %%
model = Sequential()

model.add(Conv2D(filters=32,kernel_size=(3,3),input_shape=(64,64,3),activation='relu',padding='same'))
model.add(MaxPooling2D())
model.add(Dropout(0.25))

model.add(Flatten())
model.add(Dense(1024,activation='relu'))
model.add(Dropout(0.25))
model.add(Dense(84,activation='relu'))
model.add(Dropout(0.40))
model.add(Dense(8,activation='softmax'))

# %%
model.summary()
# Out:
# Model: "sequential_10"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# conv2d_3 (Conv2D)            (None, 64, 64, 32)        896
# _________________________________________________________________
# max_pooling2d_3 (MaxPooling2 (None, 32, 32, 32)        0
# _________________________________________________________________
# dropout_19 (Dropout)         (None, 32, 32, 32)        0
# _________________________________________________________________
# flatten_6 (Flatten)          (None, 32768)             0
# _________________________________________________________________
# dense_23 (Dense)             (None, 1024)              33555456
# _________________________________________________________________
# dropout_20 (Dropout)         (None, 1024)              0
# _________________________________________________________________
# dense_24 (Dense)             (None, 84)                86100
# _________________________________________________________________
# dropout_21 (Dropout)         (None, 84)                0
# _________________________________________________________________
# dense_25 (Dense)             (None, 8)                 680
# =================================================================
# Total params: 33,643,132
# Trainable params: 33,643,132
# Non-trainable params: 0
# _________________________________________________________________

# %%
INIT_LR = 1e-2
BS=32
EPOCHS = 50

# %%
model.compile(optimizer='rmsprop',loss='categorical_crossentropy',metrics=["accuracy"])

# %%
H = model.fit(trainX,trainY,epochs=50,batch_size=32,validation_data=(testX,testY))
# Out:
# Train on 6395 samples, validate on 1129 samples
# Epoch 1/50
# 6395/6395 [==============================] - 8s 1ms/step - loss: 1.8306 - accuracy: 0.3889 - val_loss: 1.6210 - val_accuracy: 0.3818
# Epoch 2/50
# 6395/6395 [==============================] - 3s 451us/step - loss: 1.5984 - accuracy: 0.4127 - val_loss: 1.5747 - val_accuracy: 0.3977
# Epoch 3/50
# 6395/6395 [==============================] - 3s 448us/step - loss: 1.5491 - accuracy: 0.4231 - val_loss: 1.5299 - val_accuracy: 0.4066
# Epoch 4/50
# 6395/6395 [==============================] - 3s 450us/step - loss: 1.5077 - accuracy: 0.4288 - val_loss: 1.5095 - val_accuracy: 0.4057
# Epoch 5/50
# 6395/6395 [==============================] - 3s 448us/step - loss: 1.4760 - accuracy: 0.4332 - val_loss: 1.5125 - val_accuracy: 0.3995
# Epoch 6/50
# 6395/6395 [==============================] - 3s 444us/step - loss: 1.4359 - accuracy: 0.4436 - val_loss: 1.4876 - val_accuracy: 0.4119
# Epoch 7/50
# 6395/6395 [==============================] - 3s 446us/step - loss: 1.4158 - accuracy: 0.4472 - val_loss: 1.5510 - val_accuracy: 0.4154
# Epoch 8/50
# 6395/6395 [==============================] - 3s 447us/step - loss: 1.3901 - accuracy: 0.4546 - val_loss: 1.5534 - val_accuracy: 0.4004
# Epoch 9/50
# 6395/6395 [==============================] - 3s 449us/step - loss: 1.3686 - accuracy: 0.4622 - val_loss: 1.6464 - val_accuracy: 0.3490
# Epoch 10/50
# 6395/6395 [==============================] - 3s 452us/step - loss: 1.3557 - accuracy: 0.4622 - val_loss: 1.4583 - val_accuracy: 0.4030
# Epoch 11/50
# 6395/6395 [==============================] - 3s 461us/step - loss: 1.3266 - accuracy: 0.4740 - val_loss: 1.5582 - val_accuracy: 0.4145
# Epoch 12/50
# 6395/6395 [==============================] - 3s 453us/step - loss: 1.3030 - accuracy: 0.4829 - val_loss: 1.5594 - val_accuracy: 0.4190
# Epoch 13/50
# 6395/6395 [==============================] - 3s 450us/step - loss: 1.2809 - accuracy: 0.4921 - val_loss: 1.5383 - val_accuracy: 0.4119
# Epoch 14/50
# 6395/6395 [==============================] - 3s 450us/step - loss: 1.2530 - accuracy: 0.5024 - val_loss: 1.5596 - val_accuracy: 0.4030
# Epoch 15/50
# 6395/6395 [==============================] - 3s 452us/step - loss: 1.2381 - accuracy: 0.5116 - val_loss: 1.5143 - val_accuracy: 0.4092
# Epoch 16/50
# 6395/6395 [==============================] - 3s 447us/step - loss: 1.2153 - accuracy: 0.5251 - val_loss: 1.5601 - val_accuracy: 0.3959
# Epoch 17/50
# 6395/6395 [==============================] - 3s 449us/step - loss: 1.1892 - accuracy: 0.5215 - val_loss: 1.6259 - val_accuracy: 0.4260
# Epoch 18/50
# 6395/6395 [==============================] - 3s 449us/step - loss: 1.1639 - accuracy: 0.5328 - val_loss: 1.6055 - val_accuracy: 0.3995
# Epoch 19/50
# 6395/6395 [==============================] - 3s 446us/step - loss: 1.1441 - accuracy: 0.5457 - val_loss: 1.6607 - val_accuracy: 0.4225
# Epoch 20/50
# 6395/6395 [==============================] - 3s 449us/step - loss: 1.1186 - accuracy: 0.5587 - val_loss: 1.7503 - val_accuracy: 0.4136
# Epoch 21/50
# 6395/6395 [==============================] - 3s 447us/step - loss: 1.0872 - accuracy: 0.5858 - val_loss: 1.8020 - val_accuracy: 0.3924
# Epoch 22/50
# 6395/6395 [==============================] - 3s 449us/step - loss: 1.0659 - accuracy: 0.5808 - val_loss: 1.7991 - val_accuracy: 0.3888
# Epoch 23/50
# 6395/6395 [==============================] - 3s 448us/step - loss: 1.0578 - accuracy: 0.5836 - val_loss: 1.7587 - val_accuracy: 0.4163
# Epoch 24/50
# 6395/6395 [==============================] - 3s 453us/step - loss: 1.0226 - accuracy: 0.6138 - val_loss: 1.7649 - val_accuracy: 0.4074
# Epoch 25/50
# 6395/6395 [==============================] - 3s 450us/step - loss: 1.0126 - accuracy: 0.6117 - val_loss: 1.7423 - val_accuracy: 0.4074
# Epoch 26/50
# 6395/6395 [==============================] - 3s 447us/step - loss: 0.9860 - accuracy: 0.6247 - val_loss: 1.8611 - val_accuracy: 0.3986
# Epoch 27/50
# 6395/6395 [==============================] - 3s 451us/step - loss: 0.9623 - accuracy: 0.6347 - val_loss: 1.9774 - val_accuracy: 0.3959
# Epoch 28/50
# 6395/6395 [==============================] - 3s 448us/step - loss: 0.9533 - accuracy: 0.6443 - val_loss: 2.2311 - val_accuracy: 0.3977
# Epoch 29/50
# 6395/6395 [==============================] - 3s 444us/step - loss: 0.9297 - accuracy: 0.6458 - val_loss: 2.2658 - val_accuracy: 0.3995
# Epoch 30/50
# 6395/6395 [==============================] - 3s 447us/step - loss: 0.9032 - accuracy: 0.6590 - val_loss: 2.1445 - val_accuracy: 0.3942
# Epoch 31/50
# 6395/6395 [==============================] - 3s 445us/step - loss: 0.8925 - accuracy: 0.6619 - val_loss: 2.3452 - val_accuracy: 0.4083
# Epoch 32/50
# 6395/6395 [==============================] - 3s 448us/step - loss: 0.8889 - accuracy: 0.6718 - val_loss: 2.4565 - val_accuracy: 0.3933
# Epoch 33/50
# 6395/6395 [==============================] - 3s 444us/step - loss: 0.8570 - accuracy: 0.6797 - val_loss: 2.1247 - val_accuracy: 0.4269
# Epoch 34/50
# 6395/6395 [==============================] - 3s 450us/step - loss: 0.8237 - accuracy: 0.6877 - val_loss: 2.2411 - val_accuracy: 0.4083
# Epoch 35/50
# 6395/6395 [==============================] - 3s 444us/step - loss: 0.8205 - accuracy: 0.6879 - val_loss: 2.6670 - val_accuracy: 0.4039
# Epoch 36/50
# 6395/6395 [==============================] - 3s 448us/step - loss: 0.8059 - accuracy: 0.7009 - val_loss: 2.4003 - val_accuracy: 0.4021
# Epoch 37/50
# 6395/6395 [==============================] - 3s 447us/step - loss: 0.7802 - accuracy: 0.7129 - val_loss: 2.4486 - val_accuracy: 0.3924
# Epoch 38/50
# 6395/6395 [==============================] - 3s 448us/step - loss: 0.7906 - accuracy: 0.7038 - val_loss: 2.5889 - val_accuracy: 0.4057
# Epoch 39/50
# 6395/6395 [==============================] - 3s 446us/step - loss: 0.7603 - accuracy: 0.7145 - val_loss: 2.4765 - val_accuracy: 0.3986
# Epoch 40/50
# 6395/6395 [==============================] - 3s 447us/step - loss: 0.7434 - accuracy: 0.7260 - val_loss: 2.3897 - val_accuracy: 0.3959
# Epoch 41/50
# 6395/6395 [==============================] - 3s 446us/step - loss: 0.7439 - accuracy: 0.7218 - val_loss: 2.6926 - val_accuracy: 0.4172
# Epoch 42/50
# 6395/6395 [==============================] - 3s 448us/step - loss: 0.7293 - accuracy: 0.7307 - val_loss: 3.2034 - val_accuracy: 0.3933
# Epoch 43/50
# 6395/6395 [==============================] - 3s 454us/step - loss: 0.7168 - accuracy: 0.7332 - val_loss: 2.9355 - val_accuracy: 0.3968
# Epoch 44/50
# 6395/6395 [==============================] - 3s 448us/step - loss: 0.7185 - accuracy: 0.7373 - val_loss: 2.5036 - val_accuracy: 0.3844
# Epoch 45/50
# 6395/6395 [==============================] - 3s 448us/step - loss: 0.7052 - accuracy: 0.7425 - val_loss: 2.8573 - val_accuracy: 0.3995
# Epoch 46/50
# 6395/6395 [==============================] - 3s 449us/step - loss: 0.6966 - accuracy: 0.7470 - val_loss: 2.8444 - val_accuracy: 0.3933
# Epoch 47/50
# 6395/6395 [==============================] - 3s 447us/step - loss: 0.6808 - accuracy: 0.7593 - val_loss: 2.8642 - val_accuracy: 0.4057
# Epoch 48/50
# 6395/6395 [==============================] - 3s 445us/step - loss: 0.6802 - accuracy: 0.7601 - val_loss: 3.1642 - val_accuracy: 0.3853
# Epoch 49/50
# 6395/6395 [==============================] - 3s 445us/step - loss: 0.6808 - accuracy: 0.7568 - val_loss: 3.2018 - val_accuracy: 0.3968
# Epoch 50/50
# 6395/6395 [==============================] - 3s 447us/step - loss: 0.6610 - accuracy: 0.7670 - val_loss: 3.0639 - val_accuracy: 0.4039

# %% [markdown]
# ## MAJOR OVERFITTING

# %%
N = np.arange(0,EPOCHS)
plt.style.use('ggplot')
plt.figure(figsize=(8,8))
plt.plot(N,H.history['loss'],'y',label='loss')
plt.plot(N,H.history['val_loss'],'g',label='val_loss')
plt.plot(N,H.history['accuracy'],'r',label='accuracy')
plt.plot(N,H.history['val_accuracy'],'y',label='val_accuracy')
plt.legend()
plt.xlabel('#EPOCH')
plt.ylabel('Loss/Accuracy')
plt.title('Occular Disease Recognition Acc-Loss Tradeoff')
plt.show()

# %%
preds = model.predict(testX)
preds
# Out:
# array([[2.8526543e-03, 2.8244792e-03, 6.9920510e-02, ..., 1.4663034e-03,
#         2.7590033e-01, 3.4877917e-01],
#        [6.0714004e-03, 3.0575337e-02, 2.9930728e-03, ..., 2.2590399e-05,
#         9.5216417e-01, 2.1024523e-03],
#        [7.2082953e-04, 1.5947107e-02, 1.2484142e-02, ..., 1.0952351e-03,
#         7.7079517e-01, 2.2148633e-02],
#        ...,
#        [6.7689405e-03, 7.1013325e-01, 4.3388650e-02, ..., 7.3770550e-04,
#         1.5371940e-01, 6.2603615e-02],
#        [2.7517883e-02, 6.3379703e-04, 4.8864126e-01, ..., 4.4569722e-05,
#         2.6068017e-01, 9.8228492e-02],
#        [4.3552737e-03, 1.9111238e-02, 5.4381645e-01, ..., 2.9041664e-06,
#         3.5440898e-01, 7.5186916e-02]], dtype=float32)

# %%
print(classification_report(testY.argmax(axis=1),preds.argmax(axis=1),target_names=lb.classes_))
# Out:
#               precision    recall  f1-score   support
#
#          amd       0.27      0.06      0.10        48
#     cataract       0.55      0.46      0.50        52
#     diabetes       0.28      0.24      0.26       285
#     glaucoma       0.19      0.11      0.14        55
# hypertension       0.05      0.05      0.05        20
#       myopia       0.67      0.53      0.59        45
#       normal       0.49      0.71      0.58       428
#        other       0.21      0.15      0.18       196
#
#     accuracy                           0.40      1129
#    macro avg       0.34      0.29      0.30      1129
# weighted avg       0.37      0.40      0.37      1129

# %%
cnf = confusion_matrix(testY.argmax(axis=1),preds.argmax(axis=1))

# %%
plt.figure(figsize=(12,12))
sns.heatmap(cnf,annot=True,cmap='viridis',fmt='.2f',cbar=False)
plt.show()
